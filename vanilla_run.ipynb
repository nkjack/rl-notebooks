# %%
# !python algos/vanilla-pg.py --render
# Out:
# Using vanille formulation of policy gradient.
#
# Net Actions:
#  Sequential(
#   (0): Linear(in_features=4, out_features=32, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=32, out_features=2, bias=True)
#   (3): Identity()
# )
# Net States:
#  Sequential(
#   (0): Linear(in_features=4, out_features=32, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=32, out_features=1, bias=True)
#   (3): Identity()
# )
# 2020-12-19 20:36:00.841 python[61620:623832] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fa3683380f0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2020-12-19 20:36:00.842 python[61620:623832] Warning: Expected min height of view: (<NSButton: 0x7fa368357ba0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# ...

# %%
# !python algos/vanilla-pg.py --render --env "LunarLander-v2" --lr 0.01 --bs 5000 --epochs 50
# Out:
# Using vanille formulation of policy gradient.
#
# Net Actions:
#  Sequential(
#   (0): Linear(in_features=8, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=4, bias=True)
#   (5): Identity()
# )
# Net States:
#  Sequential(
#   (0): Linear(in_features=8, out_features=128, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=128, out_features=1, bias=True)
#   (5): Identity()
# )
# 2020-12-19 21:36:11.984 python[63768:674794] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fbc0fdeae10>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# ...
