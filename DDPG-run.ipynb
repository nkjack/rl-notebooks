# %%
# !python algos/ddpg.py --env "MountainCarContinuous-v0"
# Out:
# Using ddpg formulation.
#
# ep_ret -33.405072408676936 ep_len 999
# ep_ret -32.45788826902102 ep_len 999
# ep_ret -33.836844088515456 ep_len 999
# ep_ret -32.53383225724516 ep_len 999
# 2020-12-19 21:43:57.510 python[63844:679664] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fe7527bb440>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2020-12-19 21:43:57.510 python[63844:679664] Warning: Expected min height of view: (<NSButton: 0x7fe755fc80a0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2020-12-19 21:43:57.512 python[63844:679664] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fe7527c6650>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# ...
